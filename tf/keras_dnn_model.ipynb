# %%
from tensorflow import keras
import tensorflow as tf
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all, y_train_all), (x_test, y_test) = fashion_mnist.load_data()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train, x_valid, y_train, y_valid = train_test_split(x_train_all, y_train_all)

# %%
print(x_valid.shape)
print(x_test.shape)
# Out:
# (15000, 28, 28)
# (10000, 28, 28)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
for _ in range(20):
    model.add(keras.layers.Dense(300, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.compile(loss = 'sparse_categorical_crossentropy', optimizer='adam')

# %%
model.fit(x_train, y_train, epochs=1, validation_data=(x_valid, y_valid))
# Out:
# Train on 45000 samples, validate on 15000 samples
# 45000/45000 [==============================] - 37s 831us/sample - loss: 0.9690 - val_loss: 0.9487

# %%
accuracy = model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
accuracy
# Out:
# 0.986621258354187

# %% [markdown]
# ### 批归一化

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
for _ in range(20):
    model.add(keras.layers.Dense(300))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Activation('relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.compile(loss = 'sparse_categorical_crossentropy', optimizer='adam')

# %%
model.fit(x_train, y_train, epochs=10, validation_data=(x_valid, y_valid))
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/10
# 45000/45000 [==============================] - 59s 1ms/sample - loss: 0.8472 - val_loss: 0.6416
# Epoch 2/10
# 45000/45000 [==============================] - 54s 1ms/sample - loss: 0.6285 - val_loss: 0.5525
# Epoch 3/10
# 45000/45000 [==============================] - 51s 1ms/sample - loss: 0.5988 - val_loss: 0.6246
# Epoch 4/10
# 45000/45000 [==============================] - 52s 1ms/sample - loss: 0.5774 - val_loss: 0.6175
# Epoch 5/10
# 45000/45000 [==============================] - 48s 1ms/sample - loss: 0.5353 - val_loss: 0.5494
# Epoch 6/10
# 45000/45000 [==============================] - 48s 1ms/sample - loss: 0.5155 - val_loss: 0.5894
# Epoch 7/10
# 45000/45000 [==============================] - 54s 1ms/sample - loss: 0.4942 - val_loss: 0.4468
# Epoch 8/10
# 45000/45000 [==============================] - 53s 1ms/sample - loss: 0.4847 - val_loss: 0.4411
# Epoch 9/10
# 45000/45000 [==============================] - 57s 1ms/sample - loss: 0.4399 - val_loss: 0.4414
# Epoch 10/10
# 45000/45000 [==============================] - 51s 1ms/sample - loss: 0.4335 - val_loss: 0.5128

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.5506655850172043

# %% [markdown]
# ### Dropout

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
for _ in range(20):
    model.add(keras.layers.Dense(300))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Activation('relu'))
model.add(keras.layers.AlphaDropout(rate=0.5))
model.add(keras.layers.Dense(10, activation='softmax'))
model.compile(loss = 'sparse_categorical_crossentropy', optimizer='adam')
